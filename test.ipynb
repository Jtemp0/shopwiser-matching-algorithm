# %%
import pandas as pd

df = pd.read_csv('data/normalized_products.csv')

df.sample(100)
# Out:
# /var/folders/67/wknnxysn29s5zc375pft99140000gn/T/ipykernel_80858/4053800741.py:3: DtypeWarning: Columns (0: own_brand) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/normalized_products.csv')
#       supermarket  prices_(£)  prices_unit_(£)  unit  \
# 57335       Tesco        2.65            13.25    kg
# 30202   Morrisons        2.99             2.99  unit
# 7677         ASDA        2.00             5.00    kg
# 10610        ASDA        1.10             0.14  unit
# 21593   Morrisons        1.00            20.00    kg
# ...           ...         ...              ...   ...
# 28994   Morrisons        1.39             7.90     l
# 37180       Sains        9.75             1.20     l
# 20505   Morrisons        1.00             6.20    kg
# 53632       Tesco        1.80             8.40     l
# 20698   Morrisons        1.35             9.00    kg
#
#                                                 names      date  \
# ...
